# %%
# Import R libraries
from rpy2.robjects.packages import importr
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri

## Choosing a CRAN Mirror
# utils = importr('utils')
# utils.chooseCRANmirror(ind=1)
## Installing required packages
# utils.install_packages('devtools')
## Import packages
# devtools = importr('devtools')
## Import R Functions
# install_github = devtools.install_github
## Get SharedForestBinary Model
# utils.install_packages("SharedForestBinary", type="source")
# install_github("theodds/SharedForestPaper/SharedForest")
## Import R packages
SharedForest, SharedForestBinary = importr('SharedForest'), importr('SharedForestBinary')
## Allow conversions between R and Python
pandas2ri.activate()

# Import Python libraries
import datetime
import os
import pickle
import shutil
import time
import numpy as np
import pandas as pd

from scipy.stats import norm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import matplotlib
import hyperopt
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK, STATUS_FAIL
from collections import OrderedDict
from sklearn.metrics import r2_score

# Specify the column name and mapping for the labels we are trying to predict

train_path ="Data/cgiar_train.csv"
target_path ="Data/target/hours_worked_7_all.csv"



def create_train_test(data_path, label_path):
    # load features

    df = pd.read_csv(data_path, dtype={'msisdn': str})
    df.set_index('msisdn', inplace=True, drop=True)
    # load labels

    targets = pd.read_csv(label_path, dtype={"msisdn": str}, skiprows=[1]).set_index('msisdn', drop=True)


    column_name = ['gender', 'hours_worked']
  
    targets = targets[column_name]
    for c in column_name:
        targets['target_{}'.format(c)] = targets[c]
        targets.drop(c, axis=1, inplace=True)
    targets = targets.dropna().astype('str').agg('-'.join, axis=1).to_frame('target')

    # disregard unnecessary columns, map values to binary representation, and drop null values
    # drop columns that have more than a certain fraction (e.g. 50%) of null values
    threshold = 0.5
    df = df[[x for x in df.columns if (df[x].isna().sum() / df.shape[0] < threshold)]]

    # drop irrelevant columns and merge with labels
    df = df.drop(["SITE_ID", "NAME_1", "NAME_3"], axis=1)
    df = df.merge(targets, left_index=True, right_index=True, how="inner")
    
    

    # one-hot encode second distric names
    # one_hot = pd.get_dummies(df['NAME_2'])
    # fill missing values with zeros - empirically better than using mean or median
    data = df.fillna(0)
    print(data.head())

    X_train, X_test, y_train, y_test = train_test_split(data.drop('target', axis=1), data['target'], test_size=0.2,
                                                        random_state=42)
    y_train = y_train.str.split('-', expand=True)
    y_train.columns = column_name
    y_test = y_test.str.split('-', expand=True)
    y_test.columns = column_name

    for c in column_name:
        y_train[c] = pd.to_numeric(y_train[c], errors='coerce').astype(int)
        y_test.iloc[:, 0] = pd.to_numeric(y_test.iloc[:, 0], errors='coerce').astype(int)
        y_test.iloc[:, 1] = pd.to_numeric(y_test.iloc[:, 1], errors='coerce').astype(int)

    # scale features so that they have 0 mean and std equal to 1
    scaler = preprocessing.StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # scaling the continous indicators data
    y_train_ = scaler.fit_transform(pd.DataFrame(y_train.iloc[:, 1]))
    y_test_ = scaler.transform(pd.DataFrame(y_test.iloc[:, 1]))


    y_train.iloc[:, 1] = list(pd.DataFrame(y_train_)[0].values)
    y_test.iloc[:, 1] = list(pd.DataFrame(y_test_)[0].values)

    return X_train, y_train, X_test, y_test


def create_model_inputs(train_path, target_path):
    # Create train test data
    X_train, y_train, X_test, y_test = create_train_test(train_path, target_path)
    #y_test.iloc[:, 0]=y_test.iloc[:, 0].astype(float)
    y_test.iloc[:, 1] = y_test.iloc[:, 1].astype(float)
    #y_test['gender'].astype(float)
    #y_test['gender'].astype(float)

    # Convert to R dataframe
    W = ro.conversion.py2rpy(X_train)
    W_test = ro.conversion.py2rpy(X_test)

    # Split Y into delat1 and delta2
    delta1 = ro.conversion.py2rpy(y_train.iloc[:, 0])
    delta2 = ro.conversion.py2rpy(y_train.iloc[:, 1])

    return W, W_test, delta1, delta2, y_test


# Store variables


start = time.time()
def get_objective(W, W_test, delta1, delta2, y_test):
    def objective(space):
        """
        The objective contains the function to be optimized(shared forest model) .
        :param space:
        :return:
        """
        #opts = SharedForestBinary.Opts(num_burn=5000, num_thin=1, num_save=5000, num_print=10000)
        opts = SharedForest.Opts(num_burn=5000, num_thin=1, num_save=5000, num_print=1000)
        hypers = SharedForest.Hypers(X=W, Y=delta2, W=W, delta=delta1,
                                     alpha=space['alpha'],
                                     beta=int(space['beta']),
                                     gamma=space['gamma'],
                                     num_tree=int(space['num_tree']),
                                     var_tau=space['var_tau'],
                                     k=2,  ## Determines kappa
                                     k_theta=2,)

        sb = SharedForest.SharedBart(X=W,  # Training covariate matrix for continuous response
                                     Y=delta2,  # Training continuous response (standardized)
                                     W=W,  # Training covariate matrix for binary response (likely the same as X)
                                     delta=delta1,  # Training binary response
                                     X_test=W_test,  # Testing X
                                     W_test=W_test,  # Testing X
                                     hypers_=hypers, opts_=opts)



        # Helper Funtion
        def apply_fx(x):
            return np.random.binomial(p=norm.cdf(x), n=1)

        print('Getting delta1 predictions \n')
        # Get delta1 predictions
        delta_star1 = [apply_fx(x) for x in sb[8]]
        y_1 = pd.DataFrame(delta_star1).apply(lambda x: x.value_counts().index[0])
        #y_1['msisdn'] = y_test.index
        #print(y_1)
        y_1.to_csv("Data/output/delta1_hours_worked_7_all.csv", index=False)

        
        # Get delta2 predictions
        print("Getting Delta 2 prediction \n")
        delta_star2 = [apply_fx(x) for x in sb[6]]
        
        #y_2 = pd.DataFrame(delta_star2).apply(lambda x: x.value_counts().index[0])
        y_2 = pd.DataFrame(sb[6]).apply(lambda x: x.mean)
                                        
        
        y_2.to_csv("Data/output/delta2_hours_worked_7_all.csv",index=False)
        y_test.iloc[:, 1] = y_test.iloc[:, 1].astype(float)
       

        # Create F1 output score
        print("Create F1 output score \n")
        g_a = f1_score(y_test.iloc[:, 0], y_1, average='weighted')
        l_a = r2_score(y_test.iloc[:, 1], y_2) 


        hours = int((time.time() - start) // (60 * 60))
        mins = int(((time.time() - start) // 60) % 60)
        print('{} hours {} minutes have passed'.format(hours, mins))

        if np.isnan(g_a):
            status = STATUS_FAIL
        else:
            status = STATUS_OK
       
        return {'loss': 1-l_a,
                'status': status,
                'g_a': g_a,
                'l_a': l_a,
                'hyper': space}
    return objective


def summarize_trials(trials):
    results = trials.trials
    results = sorted(results, key=lambda x: -x['result']['l_a'])
    if results:
        print('Best: {}'.format(results[0]['result']))

    results = sorted(results, key=lambda x: -x['result']['l_a'])

    if results:
        print('Best test accuracy: {}'.format(results[0]['result']))


def optimize(objective, space, trials_fname=None, max_evals=1):
    if trials_fname is not None and os.path.exists(trials_fname):
        with open(trials_fname, 'rb') as trials_file:
            trials = pickle.load(trials_file)
    else:
        trials = Trials()

    best = fmin(objective,
         space=space,
         algo=tpe.suggest,
         trials=trials,
         max_evals=max_evals)

    if trials_fname is not None:
        temporary = '{}.temp'.format(trials_fname)
        with open(temporary, 'wb') as trials_file:
            pickle.dump(trials, trials_file)
        shutil.move(temporary, trials_fname)

    return trials


model_type = "hours_worked_7_all"
def main(max_evals):
    W, W_test, delta1, delta2, y_test = create_model_inputs(train_path, target_path)
    dtime = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    fname = 'Data/model/{}_model_results_{}.pickle'.format(model_type, dtime)

    objective = get_objective(W, W_test, delta1, delta2, y_test)
    # Optimization space
    space = OrderedDict([('alpha', hp.choice('alpha', range(1, 3, 1))),
                     ('beta', hp.choice('beta', range(1, 4, 1))),
                     ('gamma', hp.uniform('gamma', 0.5, 1.0)),
                     ('num_tree', hp.choice('num_tree', range(50, 200, 5))),
                     ('var_tau', hp.uniform('var_tau', 0.5, 1.0)),
                     ('k_theta', hp.choice('k_theta', range(0, 1, 1))),
                     ])
    trials = optimize(objective,
                      space,
                      trials_fname=fname,
                      max_evals=max_evals)

    summarize_trials(trials)

    return trials

trials_final = main(max_evals=1)

# %% [markdown]
# ## Load the model tunned hyperameters and results

# %%
trials = pd.read_pickle("/home/nlubalo/Documents/ubuntu_shared_folder/CGIAR_Gender/hours_worked_7_all_model_results_20220530-215847.pickle")
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': 1.0761794247904626,
#    'status': 'ok',
#    'g_a': 0.5316768025282873,
#    'l_a': -0.07617942479046258,
#    'hyper': {'alpha': 1,
#     'beta': 1,
#     'gamma': 0.883758612654199,
#     'k_theta': 0,
#     'num_tree': 55,
#     'var_tau': 0.6349118680120148}},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [0],
#     'beta': [0],
#     'gamma': [0],
#     'k_theta': [0],
#     'num_tree': [0],
#     'var_tau': [0]},
#    'vals': {'alpha': [0],
#     'beta': [0],
#     'gamma': [0.883758612654199],
#     'k_theta': [0],
#     'num_tree': [1],
#     'var_tau': [0.6349118680120148]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 19, 58, 47, 779000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 20, 3, 21, 21000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 1.0685427574807045,
#    'status': 'ok',
#    'g_a': 0.4760902255639098,
#    'l_a': -0.06854275748070449,
#    'hyper': {'alpha': 1,
#     'beta': 2,
#     'gamma': 0.5994458852175091,
#     'k_theta': 0,
#     'num_tree': 125,
#     'var_tau': 0.8767662349655391}},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [1],
#     'beta': [1],
#     'gamma': [1],
#     'k_theta': [1],
#     'num_tree': [1],
#     'var_tau': [1]},
#    'vals': {'alpha': [0],
#     'beta': [1],
#     'gamma': [0.5994458852175091],
#     'k_theta': [0],
#     'num_tree': [15],
#     'var_tau': [0.8767662349655391]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 20, 3, 21, 27000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 20, 12, 28, 759000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': 1.0969772146632035,
#    'status': 'ok',
#    'g_a': 0.5137123745819397,
#    'l_a': -0.09697721466320353,
#    'hyper': {'alpha': 1,
#     'beta': 1,
#     'gamma': 0.968485171920263,
#     'k_theta': 0,
#     'num_tree': 95,
#     'var_tau': 0.5805670827556669}},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [2],
#     'beta': [2],
#     'gamma': [2],
#     'k_theta': [2],
#     'num_tree': [2],
#     'var_tau': [2]},
#    'vals': {'alpha': [0],
#     'beta': [0],
#     'gamma': [0.968485171920263],
#     'k_theta': [0],
#     'num_tree': [9],
#     'var_tau': [0.5805670827556669]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 20, 12, 28, 764000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 20, 20, 24, 327000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': 1.0850184206473652,
#    'status': 'ok',
#    'g_a': 0.3982254486791692,
#    'l_a': -0.0850184206473652,
#    'hyper': {'alpha': 1,
#     'beta': 3,
#     'gamma': 0.9665945914463006,
#     'k_theta': 0,
#     'num_tree': 60,
#     'var_tau': 0.8132374613937545}},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [3],
#     'beta': [3],
#     'gamma': [3],
#     'k_theta': [3],
#     'num_tree': [3],
#     'var_tau': [3]},
#    'vals': {'alpha': [0],
#     'beta': [2],
#     'gamma': [0.9665945914463006],
#     'k_theta': [0],
#     'num_tree': [2],
#     'var_tau': [0.8132374613937545]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 20, 20, 24, 332000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 20, 25, 5, 566000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 1.0704897439349876,
#    'status': 'ok',
#    'g_a': 0.4951956700893156,
#    'l_a': -0.07048974393498764,
#    'hyper': {'alpha': 2,
#     'beta': 2,
#     'gamma': 0.6336658655770875,
#     'k_theta': 0,
#     'num_tree': 170,
#     'var_tau': 0.931767086786977}},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [4],
#     'beta': [4],
#     'gamma': [4],
#     'k_theta': [4],
#     'num_tree': [4],
#     'var_tau': [4]},
#    'vals': {'alpha': [1],
#     'beta': [1],
#     'gamma': [0.6336658655770875],
#     'k_theta': [0],
#     'num_tree': [24],
#     'var_tau': [0.931767086786977]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 20, 25, 5, 571000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 20, 37, 33, 987000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 1.069119427783928,
#    'status': 'ok',
#    'g_a': 0.4760902255639098,
#    'l_a': -0.06911942778392799,
#    'hyper': {'alpha': 1,
#     'beta': 2,
#     'gamma': 0.5257073444570353,
#     'k_theta': 0,
#     'num_tree': 65,
#     'var_tau': 0.8714526626213461}},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [5],
#     'beta': [5],
#     'gamma': [5],
#     'k_theta': [5],
#     'num_tree': [5],
#     'var_tau': [5]},
#    'vals': {'alpha': [0],
#     'beta': [1],
#     'gamma': [0.5257073444570353],
#     'k_theta': [0],
#     'num_tree': [3],
#     'var_tau': [0.8714526626213461]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 20, 37, 33, 992000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 20, 42, 23, 236000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': 1.0897752732734605,
#    'status': 'ok',
#    'g_a': 0.4760902255639098,
#    'l_a': -0.08977527327346047,
#    'hyper': {'alpha': 1,
#     'beta': 1,
#     'gamma': 0.7606158648918568,
#     'k_theta': 0,
#     'num_tree': 105,
#     'var_tau': 0.7930663075714024}},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [6],
#     'beta': [6],
#     'gamma': [6],
#     'k_theta': [6],
#     'num_tree': [6],
#     'var_tau': [6]},
#    'vals': {'alpha': [0],
#     'beta': [0],
#     'gamma': [0.7606158648918568],
#     'k_theta': [0],
#     'num_tree': [11],
#     'var_tau': [0.7930663075714024]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 20, 42, 23, 242000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 20, 50, 39, 160000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': 1.077370431288196,
#    'status': 'ok',
#    'g_a': 0.5316768025282873,
#    'l_a': -0.07737043128819598,
#    'hyper': {'alpha': 2,
#     'beta': 2,
#     'gamma': 0.9613734973378159,
#     'k_theta': 0,
#     'num_tree': 170,
#     'var_tau': 0.7397474046485133}},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [7],
#     'beta': [7],
#     'gamma': [7],
#     'k_theta': [7],
#     'num_tree': [7],
#     'var_tau': [7]},
#    'vals': {'alpha': [1],
#     'beta': [1],
#     'gamma': [0.9613734973378159],
#     'k_theta': [0],
#     'num_tree': [24],
#     'var_tau': [0.7397474046485133]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 20, 50, 39, 165000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 3, 56, 101000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': 1.0751204299104957,
#    'status': 'ok',
#    'g_a': 0.4760902255639098,
#    'l_a': -0.07512042991049572,
#    'hyper': {'alpha': 1,
#     'beta': 2,
#     'gamma': 0.9102185412978768,
#     'k_theta': 0,
#     'num_tree': 70,
#     'var_tau': 0.8183146715219778}},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [8],
#     'beta': [8],
#     'gamma': [8],
#     'k_theta': [8],
#     'num_tree': [8],
#     'var_tau': [8]},
#    'vals': {'alpha': [0],
#     'beta': [1],
#     'gamma': [0.9102185412978768],
#     'k_theta': [0],
#     'num_tree': [4],
#     'var_tau': [0.8183146715219778]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 3, 56, 106000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 9, 27, 293000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': 1.0752868909632427,
#    'status': 'ok',
#    'g_a': 0.37505407354001447,
#    'l_a': -0.0752868909632427,
#    'hyper': {'alpha': 1,
#     'beta': 2,
#     'gamma': 0.9416910383350567,
#     'k_theta': 0,
#     'num_tree': 50,
#     'var_tau': 0.9856506007295178}},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [9],
#     'beta': [9],
#     'gamma': [9],
#     'k_theta': [9],
#     'num_tree': [9],
#     'var_tau': [9]},
#    'vals': {'alpha': [0],
#     'beta': [1],
#     'gamma': [0.9416910383350567],
#     'k_theta': [0],
#     'num_tree': [0],
#     'var_tau': [0.9856506007295178]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 9, 27, 298000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 13, 23, 743000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': 1.0707855507824788,
#    'status': 'ok',
#    'g_a': 0.45635669721416006,
#    'l_a': -0.07078555078247883,
#    'hyper': {'alpha': 2,
#     'beta': 3,
#     'gamma': 0.5716168343973552,
#     'k_theta': 0,
#     'num_tree': 170,
#     'var_tau': 0.5170902609933041}},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [10],
#     'beta': [10],
#     'gamma': [10],
#     'k_theta': [10],
#     'num_tree': [10],
#     'var_tau': [10]},
#    'vals': {'alpha': [1],
#     'beta': [2],
#     'gamma': [0.5716168343973552],
#     'k_theta': [0],
#     'num_tree': [24],
#     'var_tau': [0.5170902609933041]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 13, 23, 747000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 25, 33, 168000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': 1.063784868891962,
#    'status': 'ok',
#    'g_a': 0.5137123745819397,
#    'l_a': -0.063784868891962,
#    'hyper': {'alpha': 2,
#     'beta': 3,
#     'gamma': 0.7204539039535351,
#     'k_theta': 0,
#     'num_tree': 115,
#     'var_tau': 0.7096901845601538}},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [11],
#     'beta': [11],
#     'gamma': [11],
#     'k_theta': [11],
#     'num_tree': [11],
#     'var_tau': [11]},
#    'vals': {'alpha': [1],
#     'beta': [2],
#     'gamma': [0.7204539039535351],
#     'k_theta': [0],
#     'num_tree': [13],
#     'var_tau': [0.7096901845601538]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 25, 33, 173000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 34, 5, 513000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': 1.065764466806341,
#    'status': 'ok',
#    'g_a': 0.45635669721416006,
#    'l_a': -0.06576446680634107,
#    'hyper': {'alpha': 1,
#     'beta': 3,
#     'gamma': 0.5373008491326039,
#     'k_theta': 0,
#     'num_tree': 115,
#     'var_tau': 0.5892433612615722}},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [12],
#     'beta': [12],
#     'gamma': [12],
#     'k_theta': [12],
#     'num_tree': [12],
#     'var_tau': [12]},
#    'vals': {'alpha': [0],
#     'beta': [2],
#     'gamma': [0.5373008491326039],
#     'k_theta': [0],
#     'num_tree': [13],
#     'var_tau': [0.5892433612615722]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 34, 5, 518000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 42, 21, 996000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': 1.0735345478657357,
#    'status': 'ok',
#    'g_a': 0.4760902255639098,
#    'l_a': -0.07353454786573566,
#    'hyper': {'alpha': 1,
#     'beta': 1,
#     'gamma': 0.5001241663024685,
#     'k_theta': 0,
#     'num_tree': 95,
#     'var_tau': 0.8146803064059733}},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [13],
#     'beta': [13],
#     'gamma': [13],
#     'k_theta': [13],
#     'num_tree': [13],
#     'var_tau': [13]},
#    'vals': {'alpha': [0],
#     'beta': [0],
#     'gamma': [0.5001241663024685],
#     'k_theta': [0],
#     'num_tree': [9],
#     'var_tau': [0.8146803064059733]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 42, 22, 1000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 49, 20, 233000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': 1.0800940821914042,
#    'status': 'ok',
#    'g_a': 0.5137123745819397,
#    'l_a': -0.08009408219140424,
#    'hyper': {'alpha': 1,
#     'beta': 2,
#     'gamma': 0.8644409945431158,
#     'k_theta': 0,
#     'num_tree': 120,
#     'var_tau': 0.7368687667210827}},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [14],
#     'beta': [14],
#     'gamma': [14],
#     'k_theta': [14],
#     'num_tree': [14],
#     'var_tau': [14]},
#    'vals': {'alpha': [0],
#     'beta': [1],
#     'gamma': [0.8644409945431158],
#     'k_theta': [0],
#     'num_tree': [14],
#     'var_tau': [0.7368687667210827]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 49, 20, 238000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 21, 58, 37, 506000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': 1.0767797101861343,
#    'status': 'ok',
#    'g_a': 0.4760902255639098,
#    'l_a': -0.07677971018613428,
#    'hyper': {'alpha': 2,
#     'beta': 1,
#     'gamma': 0.5242276183541744,
#     'k_theta': 0,
#     'num_tree': 170,
#     'var_tau': 0.5736899274310343}},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [15],
#     'beta': [15],
#     'gamma': [15],
#     'k_theta': [15],
#     'num_tree': [15],
#     'var_tau': [15]},
#    'vals': {'alpha': [1],
#     'beta': [0],
#     'gamma': [0.5242276183541744],
#     'k_theta': [0],
#     'num_tree': [24],
#     'var_tau': [0.5736899274310343]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 21, 58, 37, 511000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 22, 11, 2, 950000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': 1.0703902580714104,
#    'status': 'ok',
#    'g_a': 0.45635669721416006,
#    'l_a': -0.07039025807141042,
#    'hyper': {'alpha': 2,
#     'beta': 2,
#     'gamma': 0.5356182103710754,
#     'k_theta': 0,
#     'num_tree': 100,
#     'var_tau': 0.6473241966788843}},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [16],
#     'beta': [16],
#     'gamma': [16],
#     'k_theta': [16],
#     'num_tree': [16],
#     'var_tau': [16]},
#    'vals': {'alpha': [1],
#     'beta': [1],
#     'gamma': [0.5356182103710754],
#     'k_theta': [0],
#     'num_tree': [10],
#     'var_tau': [0.6473241966788843]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 22, 11, 2, 955000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 22, 18, 19, 472000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': 1.0717707427121803,
#    'status': 'ok',
#    'g_a': 0.4951956700893156,
#    'l_a': -0.07177074271218031,
#    'hyper': {'alpha': 1,
#     'beta': 3,
#     'gamma': 0.6204121744172146,
#     'k_theta': 0,
#     'num_tree': 85,
#     'var_tau': 0.943660204224022}},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [17],
#     'beta': [17],
#     'gamma': [17],
#     'k_theta': [17],
#     'num_tree': [17],
#     'var_tau': [17]},
#    'vals': {'alpha': [0],
#     'beta': [2],
#     'gamma': [0.6204121744172146],
#     'k_theta': [0],
#     'num_tree': [7],
#     'var_tau': [0.943660204224022]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 22, 18, 19, 476000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 22, 24, 36, 203000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': 1.068594449642408,
#    'status': 'ok',
#    'g_a': 0.45635669721416006,
#    'l_a': -0.06859444964240802,
#    'hyper': {'alpha': 2,
#     'beta': 1,
#     'gamma': 0.9010860388197852,
#     'k_theta': 0,
#     'num_tree': 155,
#     'var_tau': 0.7742260239620211}},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [18],
#     'beta': [18],
#     'gamma': [18],
#     'k_theta': [18],
#     'num_tree': [18],
#     'var_tau': [18]},
#    'vals': {'alpha': [1],
#     'beta': [0],
#     'gamma': [0.9010860388197852],
#     'k_theta': [0],
#     'num_tree': [21],
#     'var_tau': [0.7742260239620211]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 22, 24, 36, 208000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 22, 37, 4, 824000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': 1.0759282288460856,
#    'status': 'ok',
#    'g_a': 0.37505407354001447,
#    'l_a': -0.07592822884608563,
#    'hyper': {'alpha': 2,
#     'beta': 2,
#     'gamma': 0.801977314944516,
#     'k_theta': 0,
#     'num_tree': 110,
#     'var_tau': 0.7605930977223078}},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'alpha': [19],
#     'beta': [19],
#     'gamma': [19],
#     'k_theta': [19],
#     'num_tree': [19],
#     'var_tau': [19]},
#    'vals': {'alpha': [1],
#     'beta': [1],
#     'gamma': [0.801977314944516],
#     'k_theta': [0],
#     'num_tree': [12],
#     'var_tau': [0.7605930977223078]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2022, 5, 30, 22, 37, 4, 828000),
#   'refresh_time': datetime.datetime(2022, 5, 30, 22, 45, 17, 599000)}]
